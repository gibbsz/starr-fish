# %%
import pandas as pd
import numpy as np

# %%
from functions_by_ethan import * # read_list, write_list, write_fasta

# %%
pwd
# Out:
# 'C:\\Users\\zgibbs\\cellpose\\plasmid_sequencing'

# %%
# to import functions from a script, add the directory with the script to your path.

# e.g.:

# file is /Users/zgibbs/Documents/STARR-FISH/RNA-seq/code.py

# import sys
# sys.path.insert(0, '/Users/zgibbs/Documents/STARR-FISH/RNA-seq')
# import code
# Out:
# '"\nto import functions from a script, add the directory with the script to your path.\n\ne.g.:\n\nfile is /Users/zgibbs/Documents/STARR-FISH/RNA-seq/code.py\n\nimport sys\nsys.path.insert(0, \'/Users/zgibbs/Documents/STARR-FISH/RNA-seq\')\nimport code\n'

# %%
# ?write_fasta
# Out:
# Signature: write_fasta(outfile, fasta_dict)
# Docstring:
# saves a dictionary as a fasta file
#
# input:
#     outfile - a path to the output fasta
#     fasta_dict - a dictionary where the key is an entry name
#                 and the value is a genomic or protein sequence
#                 corresponding to the key name in the fasta
# File:      c:\users\zgibbs\cellpose\plasmid_sequencing\functions_by_ethan.py
# Type:      function

# %%
CRE

# %%
names = read_list('CRE_names.csv')

# %%
seqs = read_list('BC_seqs.csv')

# %%
dict_ref = {name : seq for name, seq in zip(names, seqs)}

# %%
write_fasta('300_CRE.fasta', dict_ref)
# Out:
# 116700

# %%
gtf20 = pd.read_table('CRE20_ann.txt', header=None)

# %%
gtf20
# Out:
#          0     1            2    3    4  5  6  7                  8  \
# 0   CRE001  SFv6          CDS    1  190  .  +  0  gene_id "CRE001";
# 1   CRE001  SFv6          CDS  191  570  .  +  0  gene_id "CRE001";
# 2   CRE001  SFv6  start_codon    1    3  .  +  0  gene_id "CRE001";
# 3   CRE001  SFv6   stop_codon  568  570  .  +  0  gene_id "CRE001";
# 4   CRE002  SFv6          CDS    1  190  .  +  0  gene_id "CRE002";
# ..     ...   ...          ...  ...  ... .. .. ..                ...
# 75  CRE019  SFv6   stop_codon  568  570  .  +  0  gene_id "CRE019";
# 76  CRE020  SFv6          CDS    1  190  .  +  0  gene_id "CRE020";
# 77  CRE020  SFv6          CDS  191  570  .  +  0  gene_id "CRE020";
# 78  CRE020  SFv6  start_codon    1    3  .  +  0  gene_id "CRE020";
# 79  CRE020  SFv6   stop_codon  568  570  .  +  0  gene_id "CRE020";
#
#                             9
# 0   transcript_id "CRE001.1";
# 1   transcript_id "CRE001.1";
# 2   transcript_id "CRE001.1";
# ...
