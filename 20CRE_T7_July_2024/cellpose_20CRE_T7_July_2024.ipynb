# %%
# Configure parameters and path names for segmentation

experiment = '20CRE_T7_July_2024'
segname = 'dapi'
data_folder = r'Z:\Zane_20CRE\7_17_2024__T7_20CRE'
save_dir = f'C:\\Users\\zgibbs\\cellpose\\{experiment}\\{segname}'

from ioMicro import read_im
import numpy as np
import glob
import zarr
import os

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import torch
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA RTX A6000'

# %%
# !nvidia-smi
# Out:
# Sat Aug  3 10:59:22 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 552.12                 Driver Version: 552.12         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060      WDDM  |   00000000:21:00.0  On |                  N/A |
# |  0%   44C    P8             12W /  170W |    1852MiB /  12288MiB |      6%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA RTX A6000             WDDM  |   00000000:41:00.0 Off |                  Off |
# | 30%   34C    P8             12W /  300W |    4102MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      3368    C+G   ...__8wekyb3d8bbwe\WindowsTerminal.exe      N/A      |
# |    0   N/A  N/A      7424    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A      9648    C+G   ...mpt_builder\LogiAiPromptBuilder.exe      N/A      |
# |    0   N/A  N/A     10024    C+G   ...tionsPlus\logioptionsplus_agent.exe      N/A      |
# |    0   N/A  N/A     10364    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A     10680    C+G   ...n\126.0.2592.113\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     14284    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A     14816    C+G   ....Search_cw5n1h2txyewy\SearchApp.exe      N/A      |
# |    0   N/A  N/A     16604    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A     17076    C+G   ...crosoft\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A     19084    C+G   ...air\Corsair iCUE5 Software\iCUE.exe      N/A      |
# |    0   N/A  N/A     21052    C+G   ...siveControlPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A     21268    C+G   ...cal\Microsoft\OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A     29208    C+G   ...sair iCUE5 Software\QmlRenderer.exe      N/A      |
# |    0   N/A  N/A     37916    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    1   N/A  N/A     10200      C   ...anaconda3\envs\cellpose2\python.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# # map all the hybes
# hybes =  glob.glob(data_folder+os.sep+'H*')
# # map all the fovs
# fovs = [os.path.basename(fl) for fl in glob.glob(hybes[0]+os.sep+'*.zarr')]
# def get_Hi(fld): 
#     try: return int(os.path.basename(fld)[1:]) 
#     except: return -1
    
# hybes = np.array(hybes)[np.argsort([get_Hi(hybe) for hybe in hybes ])]
# fovs.sort()

# %%
# Identify and count files (fovs) to segment 

zarr_files = r'Z:\Zane_20CRE\7_17_2024__T7_20CRE\HGFP\Conv_zscan__*.zarr'
files = list(sorted(list(glob.glob(zarr_files))))
print(f"Found {len(files)} files to segment")
# Out:
# Found 225 files to segment

# %%
# Read image data from each fov using read_im function from ioMicro

im_path = r'Z:\Zane_20CRE\7_17_2024__T7_20CRE\HGFP\*'
imgs = [read_im(im_path) for im_path in files]
# imgs_DAPI = [read_im(im_path) for im_path in files]

# %%
imgs[15][3,:,:,:].shape
# Out:
# (50, 3000, 3000)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8,8))

ax.imshow(imgs[56][4,25,:,:], cmap='gray', vmax=15000)

# %%
masks.ndim
# Out:
# 2

# %%
from cellpose import plot
import matplotlib.pyplot as plt

img1 = np.asarray(imgs[56][4,25,:,:], dtype=np.uint16) # convert image from dask array to numpy array

maski = masks
flowi = flows[0]

fig = plt.figure(figsize=(12,5))
plot.show_segmentation(fig, img1, maski, flowi)
plt.tight_layout()

# plt.savefig('/projects/ps-renlab2/zgibbs/STARR-FISH/ZaneTrit_3_3_2023/figures/cyto2_model_segmentation_plot.png', dpi=300)
plt.show()

# %%
torch.device(0)
# Out:
# device(type='cuda', index=0)

# %%
torch.cuda.get_device_name(0)

# %%
# Specify single polyA/dapi slice from each fov to use for segmentation 

for i in range(225):
    imgs[i] = imgs[i][4,25,:,:]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15,10))

ax.imshow(imgs[20], cmap='gray')

# %% [markdown]
# ## Run cellpose

# %%
# RUN CELLPOSE FOR ALL FOVS
from cellpose import models, io
from tqdm import tqdm

# DEFINE CELLPOSE MODEL
# model_type='cyto2' or pretrained_model='<path_to_model>'

# model = models.CellposeModel(gpu=True, pretrained_model=r'C:\Users\zgibbs\cellpose\HCT116_polyA_230320',
#                             device=torch.device(0))

model = models.CellposeModel(gpu=True, model_type='nuclei',
                            device=torch.device(0))

# Set the cell diameter manually (will determine automatically if 'None')
# Set the diameter to '0' if using a trained model
# HCT116 diameter = ~245

# masks, flows, styles = model.eval(imgs, channels=[0,0], diameter=0)

masks, flows, styles = [], [], []
for img in tqdm(imgs, desc='Segmented FOVs'):
    mask, flow, style = model.eval(img, channels=[0,0], diameter=100)
    masks.append(mask)
    flows.append(flow)
    styles.append(style)
# Out:
# Segmented FOVs: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 225/225 [23:03<00:00,  6.15s/it]

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.segmentation import expand_labels

newmasks = []

for mask in masks:
    newmask = mask.copy()
    for cellid, size in zip(*np.unique(mask, return_counts=True)):
        if size < 2500:
            newmask[newmask==cellid] = 0
    newmask = expand_labels(newmask, 3)
    newmasks.append(newmask)

fig, ax = plt.subplots(figsize=(10,10))

ax.imshow(imgs[50], cmap='gray')
ax.contour(newmasks[50], [0.5+x for x in np.unique(newmasks[50])], colors='b')

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(imgs[50], cmap='gray')
# ax.contour(newmasks[50], [0.5+x for x in np.unique(newmasks[50])], colors='b')

# %%
os.makedirs(save_dir)
savefiles = [os.path.join(save_dir, os.path.basename(file)) for file in files]

io.masks_flows_to_seg(imgs, newmasks, flows, file_names=savefiles, diams=100) # use 'diams=0' here for pre-trained model
io.save_to_png(imgs, newmasks, flows, file_names=savefiles)
# Out:
# Exception in thread Thread-15:
# Traceback (most recent call last):
#   File "C:\Users\zgibbs\anaconda3\envs\cellpose2\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\zgibbs\anaconda3\envs\cellpose2\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\zgibbs\anaconda3\envs\cellpose2\lib\multiprocessing\pool.py", line 519, in _handle_workers
#     cls._wait_for_updates(current_sentinels, change_notifier)
#   File "C:\Users\zgibbs\anaconda3\envs\cellpose2\lib\multiprocessing\pool.py", line 499, in _wait_for_updates
#     wait(sentinels, timeout=timeout)
#   File "C:\Users\zgibbs\anaconda3\envs\cellpose2\lib\multiprocessing\connection.py", line 879, in wait
#     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#   File "C:\Users\zgibbs\anaconda3\envs\cellpose2\lib\multiprocessing\connection.py", line 811, in _exhaustive_wait
#     res = _winapi.WaitForMultipleObjects(L, False, timeout)
# ValueError: need at most 63 handles, got a sequence of length 66

# %% [markdown]
# ### Save segmentation masks

# %%
# os.makedirs(save_dir)
savefiles = [os.path.join(save_dir, os.path.basename(file)) for file in files]

# %%
savefiles
# Out:
# ['/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__000.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__001.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__002.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__003.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__004.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__005.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__006.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__007.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__008.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__009.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__010.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__011.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__012.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__013.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__014.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__015.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__016.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__017.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__018.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__019.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__020.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__021.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__022.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__023.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__024.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__025.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__026.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__027.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__028.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__029.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__030.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__031.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__032.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__033.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__034.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__035.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__036.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__037.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__038.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__039.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__040.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__041.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__042.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__043.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__044.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__045.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__046.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__047.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__048.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__049.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__050.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__051.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__052.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__053.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__054.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__055.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__056.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__057.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__058.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__059.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__060.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__061.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__062.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__063.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__064.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__065.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__066.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__067.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__068.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__069.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__070.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__071.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__072.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__073.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__074.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__075.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__076.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__077.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__078.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__079.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__080.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__081.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__082.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__083.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__084.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__085.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__086.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__087.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__088.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__089.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__090.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__091.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__092.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__093.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__094.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__095.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__096.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__097.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__098.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__099.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__100.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__101.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__102.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__103.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__104.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__105.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__106.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__107.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__108.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__109.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__110.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__111.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__112.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__113.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__114.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__115.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__116.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__117.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__118.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__119.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__120.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__121.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__122.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__123.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__124.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__125.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__126.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__127.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__128.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__129.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__130.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__131.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__132.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__133.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__134.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__135.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__136.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__137.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__138.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__139.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__140.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__141.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__142.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__143.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__144.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__145.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__146.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__147.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__148.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__149.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__150.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__151.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__152.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__153.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__154.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__155.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__156.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__157.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__158.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__159.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__160.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__161.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__162.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__163.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__164.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__165.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__166.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__167.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__168.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__169.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__170.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__171.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__172.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__173.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__174.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__175.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__176.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__177.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__178.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__179.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__180.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__181.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__182.zarr',
#  '/projects/ps-renlab2/zgibbs/cellpose/10_12_2023__CRE-20_RNASEQ/polyA_slice20/Conv_zscan__183.zarr']

# %%
os.makedirs(save_dir)
savefiles = [os.path.join(save_dir, os.path.basename(file)) for file in files]

io.masks_flows_to_seg(imgs, newmasks, flows, file_names=savefiles, diams=0) # use 'diams=0' here for pre-trained model
io.save_to_png(imgs, newmasks, flows, file_names=savefiles)

# %% [markdown]
# ### Plot cell centers and/or spots with the segmentation masks

# %%
import numpy as np
import pandas as pd

seg11_masks = np.load('/projects/ps-renlab2/zgibbs/cellpose/ZaneTrit_3_3_2023/polyA_slice30/Conv_zscan__11_seg.npy', allow_pickle=True)[()]
seg11_coords = pd.read_csv('/projects/ps-renlab2/zgibbs/cellpose/ZaneTrit_3_3_2023/polyA_slice30/Conv_zscan__11_cp_outlines.txt', names=list(range(0,3500)), header=None)

# %%
# calculate the mean x,y coordinates for each cell in the FOV
x_coord = seg11_coords.loc[:, ::2].mean(axis=1)
y_coord = seg11_coords.loc[:, 1::2].mean(axis=1)

# create new dataframe with x,y coords and cell number in the FOV
rows = x_coord.count()
cell_num = list(range(1,rows+1))
d = {'x': x_coord, 'y': y_coord, 'mask': cell_num}
df = pd.DataFrame(data=d)

# %%
YFP_A750 = np.load('/projects/ps-renlab2/zgibbs/STARR-FISH/analysis/Conv_zscan__12--H_GFP_fits_icol0.npz', allow_pickle=True)
YFP_A750 = dict(YFP_A750)
YFP_A750['Xh']

brightness = YFP_A750['Xh'][:,7]
keep = brightness > 2500 # filter spots based on brightness (can filter based on other criteria too)
x = YFP_A750['Xh'][keep,1] # keep x coords that meet this threshold
y = YFP_A750['Xh'][keep,2] # keep y coords that meet this threshold

# Each column in decoded output array:
# 0) zc
# 1) xc
# 2) yc
# 3) bk (?)
# 4) a
# 5) habs
# 6) correlation with PSF
# 7) h (brightness)

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(15,10))

axs[0].imshow(imgs[11], cmap='gray')
axs[1].imshow(seg11_masks['masks'], cmap = 'turbo', alpha=0.8)
axs[1].imshow(seg11_masks['outlines'], cmap = 'binary_r', alpha=0.4, vmax=0.1)
# plt.scatter(df['x'], df['y'], color='k', s=5) # cell centers
# plt.scatter(y, x, color='r', s=1, alpha=0.5) # YFP spots

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(20,15))

axs[0].imshow(seg12_masks['masks'], cmap = 'turbo', alpha=0.8)
axs[0].imshow(seg12_masks['outlines'], cmap = 'binary_r', alpha=0.4, vmax=0.1)
axs[0].scatter(df['x'], df['y'], color='k', s=5) # cell centers
axs[0].scatter(y, x, color='r', s=1, alpha=0.5) # YFP spots

axs[1].imshow(imgs[12][2, 30, :, :], cmap='gray')
axs[1].contour(seg12_masks['outlines'], colors='blue')

# %%
from ioMicro import *

# %%
import matplotlib.pyplot as plt
import numpy as np

CRE = np.load(r'Z:\Zane_20CRE\7_17_2024__T7_20CRE\analysis\Conv_zscan__100--H1_fits_icol0.npz')['Xh']
h = CRE[:,7]
keep = np.where((h>400) & (h<5000))
CRE_ = CRE[keep]

img = read_im(r'Z:\Zane_20CRE\7_17_2024__T7_20CRE\H1\Conv_zscan__100.zarr')

# %%
# %gui qt5
import napari
# Out:
# ERROR:root:
#     Could not load requested Qt binding. Please ensure that
#     PyQt4 >= 4.7, PyQt5, PyQt6, PySide >= 1.0.3, PySide2, or
#     PySide6 is available, and only one is imported per session.
#
#     Currently-imported Qt library:                              None
#     PyQt5 available (requires QtCore, QtGui, QtSvg, QtWidgets): False
#     PyQt6 available (requires QtCore, QtGui, QtSvg, QtWidgets): False
#     PySide2 installed:                                          False
#     PySide6 installed:                                          False
#     Tried to load:                                              ['pyqtdefault', 'pyqt6', 'pyside6', 'pyqt5', 'pyside2']

# %%
viewer = napari.Viewer()

# %%
viewer.add_image(img)
# Out:
# <Image layer 'img [1]' at 0x208e8b03940>

# %%
napari
# Out:
# <module 'napari' from 'C:\\Users\\zgibbs\\anaconda3\\envs\\cellpose2\\lib\\site-packages\\napari\\__init__.py'>

# %%
# !nvidia-smi
# Out:
# Mon Aug 19 20:30:07 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 552.12                 Driver Version: 552.12         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060      WDDM  |   00000000:21:00.0  On |                  N/A |
# |  0%   43C    P8             12W /  170W |    5206MiB /  12288MiB |     11%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA RTX A6000             WDDM  |   00000000:41:00.0 Off |                  Off |
# | 30%   35C    P8             12W /  300W |    4204MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      3368    C+G   ...__8wekyb3d8bbwe\WindowsTerminal.exe      N/A      |
# |    0   N/A  N/A      7720    C+G   ...sair iCUE5 Software\QmlRenderer.exe      N/A      |
# |    0   N/A  N/A      9648    C+G   ...mpt_builder\LogiAiPromptBuilder.exe      N/A      |
# |    0   N/A  N/A     10024    C+G   ...tionsPlus\logioptionsplus_agent.exe      N/A      |
# |    0   N/A  N/A     10364    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A     10524    C+G   ...cal\Microsoft\OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A     10680    C+G   ...n\126.0.2592.113\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     14284    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A     14816    C+G   ....Search_cw5n1h2txyewy\SearchApp.exe      N/A      |
# |    0   N/A  N/A     16604    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A     17076    C+G   ...crosoft\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A     19084    C+G   ...air\Corsair iCUE5 Software\iCUE.exe      N/A      |
# |    0   N/A  N/A     20156    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A     21052    C+G   ...siveControlPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A     25136    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A     25712    C+G   ...n\127.0.2651.105\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     37916    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A     46336    C+G   ...bs\anaconda3\envs\napari\python.exe      N/A      |
# |    1   N/A  N/A     10200      C   ...anaconda3\envs\cellpose2\python.exe      N/A      |
# |    1   N/A  N/A     46336    C+G   ...bs\anaconda3\envs\napari\python.exe      N/A      |
# +-----------------------------------------------------------------------------------------+
